# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

driver = webdriver.Chrome(service = Service("../driver/chromedriver-linux64/chromedriver"))
driver.get("https://www.selenium.dev/")

# %% [markdown]
# eda_venv) kang@kang-pc:~/dev_ws/EDA$ mv chromedriver_linux64.zip ./driver
# (eda_venv) kang@kang-pc:~/dev_ws/EDA$ ls
# data  drive  driver  Hello.py  src  syc
# (eda_venv) kang@kang-pc:~/dev_ws/EDA$ cd ./driver
# (eda_venv) kang@kang-pc:~/dev_ws/EDA/driver$ ls
# chromedriver_linux64.zip
# (eda_venv) kang@kang-pc:~/dev_ws/EDA/driver$ unzip chromedriver_linux64.zip
# Archive:  chromedriver_linux64.zip

# %%
driver.current_url
# Out:
# 'https://www.selenium.dev/'

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight)") # x는 0 y는 body 어쩌구저쩌구

# %%
driver.execute_script("window.scrollTo(0,0)")  # 맨위로 스크롤

# %%
from selenium.webdriver.common.by import By

# %%
  #node 타입 태그 :element class: atirbute, text:text # news로 돌아가는 장치

element = driver.find_element(By.CLASS_NAME, "d-flex.justify-content-center.p-5.td-box--100")
print(element.get_attribute('innerHTML'))
# Out:
# <h2 class="selenium">News</h2>

# %%
from selenium.webdriver.common.by import By 

element = driver.find_element(By.CLASS_NAME, "d-flex.justify-content-center.p-5.td-box--100")
child = element.find_element(By.CLASS_NAME, "selenium")

print(child.text)
# Out:
# News

# %%
from selenium.webdriver.common.by import By

element = driver. find_element(By.CLASS_NAME,"d-flex.justify-content-center.p-5.td-box--100")
child = element.find_element(By.CLASS_NAME, "selenium")

print(child.text)
# Out:
# News

# %%
from selenium.webdriver.common.action_chains import ActionChains

actions = ActionChains(driver)
actions.move_to_element(child).perform() #news로 간다.

# %%
# Xpath

# %%
# 문자열은 """ 문자열 """ 로 하는것이 제일 좋다

# %%
search_btm = driver.find_element(By.XPATH, '''//*[@id="docsearch"]/button''')
search_btm.click()

# %%
from selenium.webdriver.common.keys import Keys

search_doc = driver.find_element(By.CSS_SELECTOR, "#docsearch-input")
search_doc.send_keys('find_elements')

# %%
search_doc.send_keys(Keys.ENTER)

# %%
python_tab  = driver.find_element(By.ID, "tabs-09-01-tab")
python_tab.click()  #왜 Xpath를 안쓰는가?  사소한 수정으로 PATH는 바뀌므로 xpath를 최대한 안써야한다.
#id나 tab은 잘 안바뀌므로

# %%
driver.back()

# %%
menu = driver.find_element(By.ID, "main_navbar")
li_list = menu.find_elements(By.TAG_NAME, "li")
for idx, li in enumerate(li_list):
    print("[" + str(idx) + " ] =======================")
    print(li.get_attribute('innerHTML'))
# Out:
# [0 ] =======================
#
# [1 ] =======================
# <a class="nav-link dropdown-toggle" href="#" id="navbarDropdown" role="button" data-bs-toggle="dropdown" aria-haspopup="true" aria-expanded="false">About</a><div class="dropdown-menu" aria-labelledby="navbarDropdown"><a class="dropdown-item" href="/about">About Selenium</a>
# <a class="dropdown-item" href="/project">Structure and Governance</a>
# <a class="dropdown-item" href="/events">Events</a>
# <a class="dropdown-item" href="/ecosystem">Ecosystem</a>
# <a class="dropdown-item" href="/history">History</a>
# <a class="dropdown-item" href="/getinvolved">Get Involved</a>
# <a class="dropdown-item" href="/sponsors">Sponsors</a></div>
# [2 ] =======================
# <a class="nav-link" href="/downloads"><span>Downloads</span></a>
# [3 ] =======================
# <a class="nav-link" href="/documentation"><span>Documentation</span></a>
# [4 ] =======================
# ...

# %%
about = li_list[1]
about.click()
link_list = about.find_elements(By.CLASS_NAME, "dropdown-menu")
for link in link_list:
    print(link.text)
# Out:
# About Selenium
# Structure and Governance
# Events
# Ecosystem
# History
# Get Involved
# Sponsors

# %%
history = about.find_element(By.LINK_TEXT,"History")
print(history.text)
# Out:
# History

# %%
from selenium.webdriver import ActionChains
import time

actions = ActionChains(driver)
actions.click(about)
actions.click(history)
actions.perform()

# %%
type(li_list)
# Out:
# list

# %%
driver.back()

# %%
about = li_list[1]
link_list = about.find_elements(By.CLASS_NAME,"dropdown-item")
for link in link_list:
    print(link)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="657e1ee688ac7fdd6d5b145f6faa2200", element="188EBC039EDC23C575453BC17D6EA819_element_176")>
# <selenium.webdriver.remote.webelement.WebElement (session="657e1ee688ac7fdd6d5b145f6faa2200", element="188EBC039EDC23C575453BC17D6EA819_element_177")>
# <selenium.webdriver.remote.webelement.WebElement (session="657e1ee688ac7fdd6d5b145f6faa2200", element="188EBC039EDC23C575453BC17D6EA819_element_178")>
# <selenium.webdriver.remote.webelement.WebElement (session="657e1ee688ac7fdd6d5b145f6faa2200", element="188EBC039EDC23C575453BC17D6EA819_element_179")>
# <selenium.webdriver.remote.webelement.WebElement (session="657e1ee688ac7fdd6d5b145f6faa2200", element="188EBC039EDC23C575453BC17D6EA819_element_139")>
# <selenium.webdriver.remote.webelement.WebElement (session="657e1ee688ac7fdd6d5b145f6faa2200", element="188EBC039EDC23C575453BC17D6EA819_element_180")>
# ...

# %%
type(link_list)
# Out:
# list

# %%
from bs4 import BeautifulSoup

page = driver.page_source
soup = BeautifulSoup(page, "html.parser")
print(soup.prettify())
# Out:
# <html class="no-js" itemscope="" itemtype="http://schema.org/WebPage" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1,shrink-to-fit=no" name="viewport"/>
#   <meta content="Hugo 0.110.0" name="generator"/>
#   <link href="/index.xml" rel="alternate" type="application/rss+xml"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="/favicons/favicon.ico" rel="shortcut icon"/>
#   <link href="/favicons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicons/android-36x36.png" rel="icon" sizes="36x36" type="image/png"/>
#   <link href="/favicons/android-48x48.png" rel="icon" sizes="48x48" type="image/png"/>
#   <link href="/favicons/android-72x72.png" rel="icon" sizes="72x72" type="image/png"/>
# ...

# %%
driver.close()
